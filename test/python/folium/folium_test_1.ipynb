# %%
import folium, geocoder

# %%
map=folium.Map(location=[22.66, 120.351], zoom_start=16)

# %%
gps=geocoder.osm('澄清湖').latlng

# %%
gps
# Out:
# [22.660662549999998, 120.35109204721456]

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d85949a2b7247f13d5bea6793e83d14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d85949a2b7247f13d5bea6793e83d14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0d85949a2b7247f13d5bea6793e83d14 = L.map(
#                 &quot;map_0d85949a2b7247f13d5bea6793e83d14&quot;,
#                 {
#                     center: [22.66, 120.351],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_715912ed60669e8b673335eb8c674465 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d85949a2b7247f13d5bea6793e83d14);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
map=folium.Map(location=[22.66, 120.35], zoom_start=16) 
folium.Marker(location=[22.66, 120.35] , popup="澄清湖", icon=folium.Icon(color="red")).add_to(map) 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_655dbe3f2ec9c4dbd4a481c797f42e55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_655dbe3f2ec9c4dbd4a481c797f42e55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_655dbe3f2ec9c4dbd4a481c797f42e55 = L.map(
#                 &quot;map_655dbe3f2ec9c4dbd4a481c797f42e55&quot;,
#                 {
#                     center: [22.66, 120.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec42c804330bac5eb94b0117a98b6bab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_655dbe3f2ec9c4dbd4a481c797f42e55);
#
#
#             var marker_c23869f6cedad50dc1f22749c17236cd = L.marker(
#                 [22.66, 120.35],
#                 {}
#             ).addTo(map_655dbe3f2ec9c4dbd4a481c797f42e55);
#
#
#             var icon_2050ceeff6f07a01b8e60ab2ed644fc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c23869f6cedad50dc1f22749c17236cd.setIcon(icon_2050ceeff6f07a01b8e60ab2ed644fc3);
#
#
#         var popup_23752f09c5fbfa0d2c45d1ac9df3cde3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_257db46e87a878616525adc3aef22021 = $(`&lt;div id=&quot;html_257db46e87a878616525adc3aef22021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;澄清湖&lt;/div&gt;`)[0];
#             popup_23752f09c5fbfa0d2c45d1ac9df3cde3.setContent(html_257db46e87a878616525adc3aef22021);
#
#
#         marker_c23869f6cedad50dc1f22749c17236cd.bindPopup(popup_23752f09c5fbfa0d2c45d1ac9df3cde3)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import geocoder
place='台北101'
latlng=geocoder.osm(place).latlng
map=folium.Map(location=latlng, zoom_start=16) 
folium.Marker(location=latlng , popup=place, icon=folium.Icon(color="red")).add_to(map) 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15809a2457b7a331a4561b26c48768ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15809a2457b7a331a4561b26c48768ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_15809a2457b7a331a4561b26c48768ae = L.map(
#                 &quot;map_15809a2457b7a331a4561b26c48768ae&quot;,
#                 {
#                     center: [25.03368755, 121.56482243101316],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebd31a2687fac38bf5cb642c09e15416 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15809a2457b7a331a4561b26c48768ae);
#
#
#             var marker_087eb975f836816351a71e192126310c = L.marker(
#                 [25.03368755, 121.56482243101316],
#                 {}
#             ).addTo(map_15809a2457b7a331a4561b26c48768ae);
#
#
#             var icon_d04d696fa0d08ebf942135446c215f3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_087eb975f836816351a71e192126310c.setIcon(icon_d04d696fa0d08ebf942135446c215f3a);
#
#
#         var popup_b8925c4339d79eedbaa1d855f96737fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f5865afbd842cdbf6aa2ddc45baaf0ad = $(`&lt;div id=&quot;html_f5865afbd842cdbf6aa2ddc45baaf0ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台北101&lt;/div&gt;`)[0];
#             popup_b8925c4339d79eedbaa1d855f96737fe.setContent(html_f5865afbd842cdbf6aa2ddc45baaf0ad);
#
#
#         marker_087eb975f836816351a71e192126310c.bindPopup(popup_b8925c4339d79eedbaa1d855f96737fe)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests

# %%
url="https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"

# %%
data=requests.get(url).json()

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
# {'sno': '500101001',
#  'sna': 'YouBike2.0_捷運科技大樓站',
#  'tot': 28,
#  'sbi': 15,
#  'sarea': '大安區',
#  'mday': '2022-08-31 15:15:39',
#  'lat': 25.02605,
#  'lng': 121.5436,
#  'ar': '復興南路二段235號前',
#  'sareaen': 'Daan Dist.',
#  'snaen': 'YouBike2.0_MRT Technology Bldg. Sta.',
#  'aren': 'No.235， Sec. 2， Fuxing S. Rd.',
#  'bemp': 13,
#  'act': '1',
#  'srcUpdateTime': '2022-08-31 15:16:13',
#  'updateTime': '2022-08-31 15:16:07',
#  'infoTime': '2022-08-31 15:15:39',
#  'infoDate': '2022-08-31'}

# %%
import folium
place='台北市'
latlng=geocoder.osm(place).latlng
map=folium.Map(location=latlng, zoom_start=16)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e1837c710f7108b69dd101e9b867a95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e1837c710f7108b69dd101e9b867a95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0e1837c710f7108b69dd101e9b867a95 = L.map(
#                 &quot;map_0e1837c710f7108b69dd101e9b867a95&quot;,
#                 {
#                     center: [25.0375198, 121.5636796],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc5d0bab8c12375b55b15f02f66579ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e1837c710f7108b69dd101e9b867a95);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
import folium 
import geocoder
place='台北市'
latlng=geocoder.osm(place).latlng
map=folium.Map(location=latlng, zoom_start=16)
url="https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"
data=requests.get(url).json()
for i in data:
    folium.Marker(location=(i['lat'], i['lng']) , popup=i['sna']).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e45cbe5370835c08157bcc411cf6d7fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e45cbe5370835c08157bcc411cf6d7fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e45cbe5370835c08157bcc411cf6d7fb = L.map(
#                 &quot;map_e45cbe5370835c08157bcc411cf6d7fb&quot;,
#                 {
#                     center: [25.0375198, 121.5636796],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1499c17d5541b7f7fa9e0284c3520be7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e45cbe5370835c08157bcc411cf6d7fb);
#
#
#             var marker_a06df324eefeb8127d6a8fcec1e48637 = L.marker(
#                 [25.02605, 121.5436],
#                 {}
#             ).addTo(map_e45cbe5370835c08157bcc411cf6d7fb);
#
#
#         var popup_7ffa4eea155d522c0dfe41d9a70f0afd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6a51c0648cd5e6cebc66d63a1124747c = $(`&lt;div id=&quot;html_6a51c0648cd5e6cebc66d63a1124747c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;YouBike2.0_捷運科技大樓站&lt;/div&gt;`)[0];
#             popup_7ffa4eea155d522c0dfe41d9a70f0afd.setContent(html_6a51c0648cd5e6cebc66d63a1124747c);
#
#
#         marker_a06df324eefeb8127d6a8fcec1e48637.bindPopup(popup_7ffa4eea155d522c0dfe41d9a70f0afd)
#         ;
#
#
#
#
#             var marker_c85aa997c776d1a3bf243a1d9c57fbaa = L.marker(
#                 [25.02565, 121.54357],
#                 {}
#             ).addTo(map_e45cbe5370835c08157bcc411cf6d7fb);
#
#
#         var popup_f8b6631918bacb7ae0ee8f95a60d8aa8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3b7707318e7129611329bf772fdada5e = $(`&lt;div id=&quot;html_3b7707318e7129611329bf772fdada5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;YouBike2.0_復興南路二段273號前&lt;/div&gt;`)[0];
#             popup_f8b6631918bacb7ae0ee8f95a60d8aa8.setContent(html_3b7707318e7129611329bf772fdada5e);
#
#
#         marker_c85aa997c776d1a3bf243a1d9c57fbaa.bindPopup(popup_f8b6631918bacb7ae0ee8f95a60d8aa8)
#         ;
#
#
#
#
#             var marker_60ef362f8cad1d4f35ecb591531643f4 = L.marker(
#                 [25.02429, 121.54124],
#                 {}
#             ).addTo(map_e45cbe5370835c08157bcc411cf6d7fb);
#
#
#         var popup_cf0bb46fe8277a32e28748eb7dc8cfc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e0a33f4e9aacebc6f1c37f34d6f93cf7 = $(`&lt;div id=&quot;html_e0a33f4e9aacebc6f1c37f34d6f93cf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;YouBike2.0_國北教大實小東側門&lt;/div&gt;`)[0];
#             popup_cf0bb46fe8277a32e28748eb7dc8cfc9.setContent(html_e0a33f4e9aacebc6f1c37f34d6f93cf7);
#
#
#         marker_60ef362f8cad1d4f35ecb591531643f4.bindPopup(popup_cf0bb46fe8277a32e28748eb7dc8cfc9)
#         ;
#
#
#
#
#             var marker_64cf0f17abb32a0207f9414cea4305b3 = L.marker(
#                 [25.02351, 121.54282],
#                 {}
#             ).addTo(map_e45cbe5370835c08157bcc411cf6d7fb);
#
#
#         var popup_673f02f8f82f4769bea6302d92d3465a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d38357c4fc1613dd1dee14cbab29a8dd = $(`&lt;div id=&quot;html_d38357c4fc1613dd1dee14cbab29a8dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;YouBike2.0_和平公園東側&lt;/div&gt;`)[0];
#             popup_673f02f8f82f4769bea6302d92d3465a.setContent(html_d38357c4fc1613dd1dee14cbab29a8dd);
#
#
#         marker_64cf0f17abb32a0207f9414cea4305b3.bindPopup(popup_673f02f8f82f4769bea6302d92d3465a)
#         ;
#
#
#
#
#             var marker_24220504c9cfd84bc99b7e695096b819 = L.marker(
#                 [25.02153, 121.54299],
#                 {}
#             ).addTo(map_e45cbe5370835c08157bcc411cf6d7fb);
#
#
#         var popup_f0228752e234a2fb1d8c97bb7d240ab4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dba829baae353d2725c2bf153cb5bcd6 = $(`&lt;div id=&quot;html_dba829baae353d2725c2bf153cb5bcd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;YouBike2.0_辛亥復興路口西北側&lt;/div&gt;`)[0];
#             popup_f0228752e234a2fb1d8c97bb7d240ab4.setContent(html_dba829baae353d2725c2bf153cb5bcd6);
#
#
#         marker_24220504c9cfd84bc99b7e695096b819.bindPopup(popup_f0228752e234a2fb1d8c97bb7d240ab4)
#         ;
#
#
#
#
#             var marker_96b83f1581e19ac9dabc3790e9638fa9 = L.marker(
#                 [25.02429, 121.54328],
#                 {}
#             ).addTo(map_e45cbe5370835c08157bcc411cf6d7fb);
#
#
#         var popup_b1f1e8c0a2aa171fe72df464ad351d26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_051445c254da790c1c209089f889ab27 = $(`&lt;div id=&quot;html_051445c25
